# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('train.csv')

# %%
# Show first observations in dataset.
df.head(10)
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4    var_5  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607  -9.2834
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622   7.0433
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825  -9.0837
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846  -1.8361
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772   2.4486
# 5  train_5       0  11.4763 -2.3182  12.6080  8.6264  10.9621   3.5609
# 6  train_6       0  11.8091 -0.0832   9.3494  4.2916  11.1355  -8.0198
# 7  train_7       0  13.5580 -7.9881  13.8776  7.5985   8.6543   0.8310
# 8  train_8       0  16.1071  2.4426  13.9307  5.6327   8.8014   6.1630
# 9  train_9       0  12.5088  1.9743   8.8960  5.4508  13.6043 -16.2859
#
#     var_6    var_7  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  5.1187  18.6266  ...   4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# ...

# %%
# Check if there are any missing values.
df.isnull().sum()
# Out:
# Unnamed: 0           0
# ID                   0
# Name                 0
# Age                  0
# Photo                0
#                   ...
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Release Clause    1564
# Length: 89, dtype: int64

# %%
# Remove ID_code column
df.drop(['ID_code'], axis=1, inplace=True)

# %%
# mean of each variable according to target
df.groupby('target').mean()
# Out:
#             var_0     var_1      var_2     var_3      var_4     var_5  \
# target
# 0       10.626681 -1.695770  10.665876  6.788979  11.072412 -5.146736
# 1       11.156418 -1.017613  11.156633  6.864113  11.131337 -4.336522
#
#            var_6      var_7     var_8     var_9  ...   var_190  var_191  \
# target                                           ...
# 0       5.389620  16.549306  0.262347  7.584907  ...  3.149130  7.39080
# 1       5.581966  16.514917  0.479432  7.409064  ...  3.998064  7.86456
#
#          var_192   var_193    var_194   var_195   var_196   var_197  \
# target
# 0       1.949017  3.355403  18.017716 -0.155601  2.260297  8.919032
# 1       1.738266  3.120260  17.779568 -0.021130  2.688583  8.810815
#
#           var_198   var_199
# target
# 0       15.924058 -3.415273
# 1       15.393283 -2.532243
#
# [2 rows x 200 columns]

# %%
# Count number of values for each target
a = df[df['target'] == 0].count()
b = df[df['target'] == 1].count()
print(a)
print(b)
# Out:
# target     179902
# var_0      179902
# var_1      179902
# var_2      179902
# var_3      179902
#             ...
# var_195    179902
# var_196    179902
# var_197    179902
# var_198    179902
# var_199    179902
# Length: 201, dtype: int64
# target     20098
# var_0      20098
# var_1      20098
# var_2      20098
# var_3      20098
#            ...
# var_195    20098
# var_196    20098
# var_197    20098
# var_198    20098
# var_199    20098
# Length: 201, dtype: int64

# %%
counts = df.groupby('target').count()

# %%
counts
# Out:
#          var_0   var_1   var_2   var_3   var_4   var_5   var_6   var_7  \
# target
# 0       179902  179902  179902  179902  179902  179902  179902  179902
# 1        20098   20098   20098   20098   20098   20098   20098   20098
#
#          var_8   var_9  ...  var_190  var_191  var_192  var_193  var_194  \
# target                  ...
# 0       179902  179902  ...   179902   179902   179902   179902   179902
# 1        20098   20098  ...    20098    20098    20098    20098    20098
#
#         var_195  var_196  var_197  var_198  var_199
# target
# 0        179902   179902   179902   179902   179902
# 1         20098    20098    20098    20098    20098
#
# [2 rows x 200 columns]

# %%
# Give interpretation for std, min, max, mean
df.describe()
# Out:
#               target          var_0          var_1          var_2  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        0.100490      10.679914      -1.627622      10.715192
# std         0.300653       3.040051       4.050044       2.640894
# min         0.000000       0.408400     -15.043400       2.117100
# 25%         0.000000       8.453850      -4.740025       8.722475
# 50%         0.000000      10.524750      -1.608050      10.580000
# 75%         0.000000      12.758200       1.358625      12.516700
# max         1.000000      20.315000      10.376800      19.353000
#
#                var_3          var_4          var_5          var_6  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        6.796529      11.078333      -5.065317       5.408949
# std         2.043319       1.623150       7.863267       0.866607
# min        -0.040200       5.074800     -32.562600       2.347300
# ...

# %%
# Show mean of var_0 by using indexing
mean_var_0 = df.reset_index().groupby('index')['var_0'].mean()

# %%
min_mean = mean_var_0.min()
min_mean
# Out:
# 0.4084

# %%
# Filter var_0 variable from minimum to mean
filter_mean_df = df[mean_var_0 > min_mean]
filter_mean_df
# Out:
#         target    var_0   var_1    var_2   var_3    var_4    var_5   var_6  \
# 0            0   8.9255 -6.7863  11.9081  5.0930  11.4607  -9.2834  5.1187
# 1            0  11.5006 -4.1473  13.8588  5.3890  12.3622   7.0433  5.6208
# 2            0   8.6093 -2.7457  12.0805  7.8928  10.5825  -9.0837  6.9427
# 3            0  11.0604 -2.1518   8.9522  7.1957  12.5846  -1.8361  5.8428
# 4            0   9.8369 -1.4834  12.8746  6.6375  12.2772   2.4486  5.9405
# ...        ...      ...     ...      ...     ...      ...      ...     ...
# 199995       0  11.4880 -0.4956   8.2622  3.5142  10.3404  11.6081  5.6709
# 199996       0   4.9149 -2.4484  16.7052  6.6345   8.3096 -10.5628  5.8802
# 199997       0  11.2232 -5.0518  10.5127  5.6456   9.3410  -5.4086  4.5555
# 199998       0   9.7148 -8.6098  13.6104  5.7930  12.5173   0.5339  6.0479
# 199999       0  10.8762 -5.7105  12.1183  8.0328  11.5577   0.3488  5.2839
#
# ...

# %%
# Filter var_6 greater than 5 and var_196 less than 2
filter_var6_var_196 = df[(df['var_6'] > 5) & (df['var_196'] < 2)]
filter_var6_var_196
# Out:
#         target    var_0   var_1    var_2   var_3    var_4    var_5   var_6  \
# 2            0   8.6093 -2.7457  12.0805  7.8928  10.5825  -9.0837  6.9427
# 3            0  11.0604 -2.1518   8.9522  7.1957  12.5846  -1.8361  5.8428
# 11           0  12.7188 -7.9750  10.3757  9.0101  12.8570 -12.0852  5.6464
# 14           0  13.8080  5.0514  17.2611  8.5120  12.8517  -9.1622  5.7327
# 16           0   5.0615  0.2689  15.1325  3.6587  13.5276  -6.5477  5.2757
# ...        ...      ...     ...      ...     ...      ...      ...     ...
# 199990       1  14.1475  1.8568  11.0066  3.6779  12.1944 -16.5936  5.3217
# 199991       0   9.9909  2.5523  11.9653  6.3958  13.5497  -9.5293  6.0864
# 199994       0  12.3925 -5.8821  11.2323  3.9237  10.4509  10.7262  7.0503
# 199996       0   4.9149 -2.4484  16.7052  6.6345   8.3096 -10.5628  5.8802
# 199999       0  10.8762 -5.7105  12.1183  8.0328  11.5577   0.3488  5.2839
#
# ...

# %%
# Show observations between 20000 and 30000 for 11th column
df[df.columns[11:12]].iloc[20000:30001]
# Out:
#         var_10
# 20000   4.8219
# 20001   4.1234
# 20002   1.5339
# 20003   5.2597
# 20004  10.2969
# ...        ...
# 29996   8.3554
# 29997  -1.3356
# 29998  -0.0461
# 29999  -1.9111
# 30000  -6.9853
#
# [10001 rows x 1 columns]

# %%
# Create features list including variables from var_0 to var_9
features_list = df[['var_0', 'var_1', 'var_2', 'var_3', 'var_4', 'var_5', 'var_6', 'var_7', 'var_8', 'var_9']]

# %%
# Find correlations in features
features_list.corr()
# Out:
#           var_0     var_1     var_2     var_3     var_4     var_5     var_6  \
# var_0  1.000000 -0.000544  0.006573  0.003801  0.001326  0.003046  0.006983
# var_1 -0.000544  1.000000  0.003980  0.000010  0.000303 -0.000902  0.003258
# var_2  0.006573  0.003980  1.000000  0.001001  0.000723  0.001569  0.000883
# var_3  0.003801  0.000010  0.001001  1.000000 -0.000322  0.003253 -0.000774
# var_4  0.001326  0.000303  0.000723 -0.000322  1.000000 -0.001368  0.000049
# var_5  0.003046 -0.000902  0.001569  0.003253 -0.001368  1.000000  0.002588
# var_6  0.006983  0.003258  0.000883 -0.000774  0.000049  0.002588  1.000000
# var_7  0.002429  0.001511 -0.000991  0.002500  0.004549 -0.000995 -0.002548
# var_8  0.004962  0.004098  0.002648  0.003553  0.001194  0.000147 -0.001188
# var_9 -0.002613 -0.000832 -0.001932 -0.000826 -0.000918 -0.005279 -0.005697
#
#           var_7     var_8     var_9
# var_0  0.002429  0.004962 -0.002613
# var_1  0.001511  0.004098 -0.000832
# ...

# %%
# Sort most correlated variables in features
features_list = features_list.unstack()

# %%
lst = []
for i in features_list:
    if i > 0.9 and i < 1:
        lst.append(i)

# %%
series = pd.Series(lst)

series = series.drop_duplicates()
unique_list = series.tolist()
unique_list.sort()
len(unique_list)
# Out:
# 985

# %%
# Show top 10 most correlated variables in features
unique_list[:-10:-1]
# Out:
# [0.9999, 0.9998, 0.9997, 0.9996, 0.9995, 0.9994, 0.9993, 0.9992, 0.9991]

# %%
# Remove outliers from dataset
window_size = 10
outliers_mask = pd.Series(False, index=df.index)
for i in df.columns:
    mean = df[i].ewm(window_size).mean()
    std = df[i].ewm(window_size).std()
    std[0] = 0 #the first value turns into NaN because of no data
    mean_plus_std = mean + 2*std
    mean_minus_std = mean - 2*std
    is_outlier = (df[i] > mean_plus_std) | (df[i] < mean_minus_std)
    outliers = df[is_outlier]
    outliers_mask = outliers_mask | is_outlier
print(outliers)
# Out:
#         target    var_0   var_1    var_2   var_3    var_4    var_5   var_6  \
# 168          0   8.9255  1.7408  11.1104  6.3121  10.5106   0.5307  5.1792
# 387          0  18.0587 -0.8031  10.7640  6.3136  10.9081  -3.1534  5.3388
# 607          0   9.7372  0.8541  11.6188  5.4716  12.3037 -13.7484  6.2813
# 660          0  13.0253 -5.5124   8.7477  9.3157  10.4322 -16.5303  5.2034
# 1657         0  14.9984 -3.4894  14.6515  5.9306  10.7323 -12.0074  6.5006
# ...        ...      ...     ...      ...     ...      ...      ...     ...
# 199184       0  13.0623  0.9661  11.0521  8.9585  10.9436   4.8228  6.6789
# 199215       0  10.6914  3.8223   6.5591  7.2579   9.1461  -5.9369  5.3603
# 199305       0   9.8647 -6.1286  10.7821  7.8720  10.7046  -1.3862  5.7509
# 199495       0   9.6348  0.1691   8.6162  5.3384   8.0941  -5.9138  5.3410
# 199675       0  11.4608  5.0273  10.8818  3.1570  12.1772   9.8169  6.1611
#
# ...

# %%
filtered_df = df[~outliers_mask]
filtered_df
# Out:
#         target    var_0   var_1    var_2   var_3    var_4    var_5   var_6  \
# 0            0   8.9255 -6.7863  11.9081  5.0930  11.4607  -9.2834  5.1187
# 1            0  11.5006 -4.1473  13.8588  5.3890  12.3622   7.0433  5.6208
# 2            0   8.6093 -2.7457  12.0805  7.8928  10.5825  -9.0837  6.9427
# 3            0  11.0604 -2.1518   8.9522  7.1957  12.5846  -1.8361  5.8428
# 4            0   9.8369 -1.4834  12.8746  6.6375  12.2772   2.4486  5.9405
# ...        ...      ...     ...      ...     ...      ...      ...     ...
# 199992       0  12.2825  2.6918  15.4684  6.4262  10.9863   9.9659  4.5030
# 199993       0  13.2152 -5.8006   9.7260  6.5910  12.4612  -7.1652  6.0666
# 199995       0  11.4880 -0.4956   8.2622  3.5142  10.3404  11.6081  5.6709
# 199997       0  11.2232 -5.0518  10.5127  5.6456   9.3410  -5.4086  4.5555
# 199999       0  10.8762 -5.7105  12.1183  8.0328  11.5577   0.3488  5.2839
#
# ...

# %%
sns.boxplot(data = df, x = df['var_0'])
# Out:
# <Axes: xlabel='var_0'>

# %%
sns.boxplot(data = filtered_df, x = filtered_df['var_0'])
# Out:
# <Axes: xlabel='var_0'>
